# %%
import os
os.chdir("..")

# %%
from HybridMlp import HybridMlp
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
from tensorflow import keras
from keras.models import Sequential

from keras.layers import Dense
from sklearn.metrics import accuracy_score
from mealpy.swarm_based import GWO
from mealpy.swarm_based import ACOR
from mealpy.swarm_based import PSO
from mealpy.evolutionary_based import FPA
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data_training = pd.read_csv(r"og data/data_training.csv")
dataTrain = pd.read_csv(r"og data/dataTrain.csv")
dataTest = pd.read_csv(r"og data/dataTest.csv")


y = pd.read_csv("y.csv")
yTrain = pd.read_csv("yTrain.csv")
yTest = pd.read_csv("yTest.csv")

y = y.iloc[:,1]
yTrain  = yTrain.iloc[:,1]
yTest = yTest.iloc[:,1]

# %%
def confusionMatrix(yTest, yhat):
        y_true = yTest
        y_pred = yhat

        # Generate confusion matrix
        cm = confusion_matrix(y_true, y_pred)
        print("Confusion Matrix:")
        print(cm)


        # Calculate metrics
        accuracy = accuracy_score(y_true, y_pred)
        precision = precision_score(y_true, y_pred, average='macro')
        recall = recall_score(y_true, y_pred, average='macro')
        f1 = f1_score(y_true, y_pred, average='macro')

        print("\nMetrics:")
        print(f"Accuracy: {accuracy}")
        print(f"Precision: {precision}")
        print(f"Recall: {recall}")
        print(f"F1 Score: {f1}")

# %%
n_hidden_nodes = [64,64,6]
epoch = 50
pop_size = 50

# define model
model = HybridMlp(dataTrain, dataTest, yTrain, yTest, n_hidden_nodes, epoch, pop_size, 'PSO')
# fit model
model.training()

# access to the best model - best set of weights - the final weights of neural network
# model.solution

# evaluate on test set
yhat = model.prediction(solution=model.solution, x_data=dataTest)
yhat = np.argmax(yhat, axis=-1).astype('int')
acc = accuracy_score(yTest, yhat)
print('Accuracy: %.3f' % acc)
confusionMatrix(yTest, yhat)
# Out:
# c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\keras\src\layers\core\input_layer.py:25: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step
# ...
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 8
#       6 model = HybridMlp(dataTrain, dataTest, yTrain, yTest, n_hidden_nodes, epoch, pop_size, 'PSO')
#       7 # fit model
# ----> 8 model.training()
#      10 # access to the best model - best set of weights - the final weights of neural network
#      11 # model.solution
#      12
#      13 # evaluate on test set
#      14 yhat = model.prediction(solution=model.solution, x_data=dataTest)
#
# File c:\Users\Lenovo\Desktop\practice+projex\jupyter notebooks\HAR\HybridMlp.py:87, in HybridMlp.training(self)
#      84 else:
#      85  self.optimizer = FPA.OriginalFPA(self.problem, self.epoch, self.pop_size)
# ---> 87 self.solution, self.best_fit = self.optimizer.solve(self.problem)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\mealpy\optimizer.py:314, in Optimizer.solve(self, problem, mode, starting_positions, n_workers, termination)
#     311 time_epoch = time.perf_counter()
#     313 ## Evolve method will be called in child class
# --> 314 self.evolve(epoch)
#     316 # Update global best position, the population is sorted or not depended on algorithm's strategy
#     317 pop_temp, self.g_best = self.update_global_best_solution(self.pop)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\mealpy\swarm_based\PSO.py:122, in OriginalPSO.evolve(self, epoch)
#     120     pop_new.append(agent)
#     121     if self.mode not in self.AVAILABLE_MODES:
# --> 122         pop_new[-1][self.ID_TAR] = self.get_target_wrapper(pos_new)
#     123 if self.mode in self.AVAILABLE_MODES:
#     124     pop_new = self.update_target_wrapper_population(pop_new)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\mealpy\optimizer.py:164, in Optimizer.get_target_wrapper(self, position, counted)
#     162 if counted:
#     163     self.nfe_counter += 1
# --> 164 objs = self.problem.fit_func(position)
#     165 if not self.problem.obj_is_list:
#     166     objs = [objs]
#
# File c:\Users\Lenovo\Desktop\practice+projex\jupyter notebooks\HAR\HybridMlp.py:94, in HybridMlp.fitness_function(self, solution)
#      89 def fitness_function(self, solution):  # Used in training process
#      90     # Assumption that we have 3 layer , 1 input layer, 1 hidden layer and 1 output layer
#      91     # number of nodes are 3, 2, 3
#      92     # solution = [w11, w21, w31, w12, w22, w32, b1, b2, wh11, wh21, wh12, wh22, wh13, wh23, bo1, bo2, bo3 ]
#      93     self.decode_solution(solution)
# ---> 94     yhat = self.model.predict(self.X_train)
#      95     yhat = np.argmax(yhat, axis=-1).astype('int')
#      96     acc = accuracy_score(self.y_train, yhat)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:442, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     437 @traceback_utils.filter_traceback
#     438 def predict(
#     439     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     440 ):
#     441     # Create an iterator that yields batches of input data.
# --> 442     epoch_iterator = TFEpochIterator(
#     443         x=x,
#     444         batch_size=batch_size,
#     445         steps_per_epoch=steps,
#     446         shuffle=False,
#     447         distribute_strategy=self.distribute_strategy,
#     448         steps_per_execution=self.steps_per_execution,
#     449     )
#     451     # Container that configures and calls callbacks.
#     452     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:625, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     623 super().__init__(*args, **kwargs)
#     624 self._distribute_strategy = distribute_strategy
# --> 625 dataset = self._get_iterator()
#     626 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     627     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     628         dataset
#     629     )
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:634, in TFEpochIterator._get_iterator(self)
#     633 def _get_iterator(self):
# --> 634     return self.data_adapter.get_tf_dataset()
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:236, in ArrayDataAdapter.get_tf_dataset(self)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
# --> 236 dataset = slice_inputs(indices_dataset, self._inputs)
#     238 options = tf.data.Options()
#     239 options.experimental_distribute.auto_shard_policy = (
#     240     tf.data.experimental.AutoShardPolicy.DATA
#     241 )
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:197, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs(indices_dataset, inputs)
#     191 inputs = array_slicing.convert_to_sliceable(
#     192     self._inputs, target_backend="tensorflow"
#     193 )
#     194 inputs = tree.lists_to_tuples(inputs)
#     196 dataset = tf.data.Dataset.zip(
# --> 197     (indices_dataset, tf.data.Dataset.from_tensors(inputs).repeat())
#     198 )
#     200 def grab_batch(i, data):
#     202     def grab_one(x):
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:741, in DatasetV2.from_tensors(tensors, name)
#     737 # Loaded lazily due to a circular dependency (dataset_ops ->
#     738 # from_tensors_op -> dataset_ops).
#     739 # pylint: disable=g-import-not-at-top,protected-access
#     740 from tensorflow.python.data.ops import from_tensors_op
# --> 741 return from_tensors_op._from_tensors(tensors, name)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\data\ops\from_tensors_op.py:23, in _from_tensors(tensors, name)
#      22 def _from_tensors(tensors, name):  # pylint: disable=unused-private-name
# ---> 23   return _TensorDataset(tensors, name)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\data\ops\from_tensors_op.py:31, in _TensorDataset.__init__(self, element, name)
#      29 def __init__(self, element, name=None):
#      30   """See `tf.data.Dataset.from_tensors` for details."""
# ---> 31   element = structure.normalize_element(element)
#      32   self._structure = structure.type_spec_from_value(element)
#      33   self._tensors = structure.to_tensor_list(self._structure, element)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\data\util\structure.py:134, in normalize_element(element, element_signature)
#     131       else:
#     132         dtype = getattr(spec, "dtype", None)
#     133         normalized_components.append(
# --> 134             ops.convert_to_tensor(t, name="component_%d" % i, dtype=dtype))
#     135 return nest.pack_sequence_as(pack_as, normalized_components)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\framework\ops.py:713, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     711 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     712 preferred_dtype = preferred_dtype or dtype_hint
# --> 713 return tensor_conversion_registry.convert(
#     714     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     715 )
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\framework\constant_tensor_conversion.py:29, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#      26 from tensorflow.python.framework import constant_op  # pylint: disable=g-import-not-at-top
#      28 _ = as_ref
# ---> 29 return constant_op.constant(v, dtype=dtype, name=name)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:289, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287     with trace.Trace("tf.constant"):
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:301, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     297 def _constant_eager_impl(
#     298     ctx, value, dtype, shape, verify_shape
#     299 ) -> ops._EagerTensorBase:
#     300   """Creates a constant on the current device."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# File c:\Users\Lenovo\Desktop\git_prac\flask_prac\venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:96, in convert_to_eager_tensor(value, ctx, dtype)
#      76 """Converts the given `value` to an `EagerTensor`.
#      77
#      78 Note that this function could return cached copies of created constants for
#    (...)
#      90   TypeError: if `dtype` is not compatible with the type of t.
#      91 """
#      92 if isinstance(value, np.ndarray):
#      93   # Make a copy explicitly because the EagerTensor might share the underlying
#      94   # memory with the input array. Without this copy, users will be able to
#      95   # modify the EagerTensor after its creation by changing the input array.
# ---> 96   value = value.copy()
#      97 if isinstance(value, ops.EagerTensor):
#      98   if dtype is not None and value.dtype != dtype:
#
# KeyboardInterrupt:
